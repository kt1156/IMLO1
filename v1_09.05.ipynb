# %%
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# define transformations
data_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),    # mean val for each rgb channel, corresponding std
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

training_data = datasets.Flowers102(
    root="data",
    split="train",
    download=True,
    transform=data_transform
)

test_data = datasets.Flowers102(
    root="data",
    split="test",
    download=True,
    transform=data_transform
)

train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64)

# %%
import torch.nn as nn
import torch.nn.functional as F

# Get cpu, gpu or mps device for training.

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
import scipy.io 

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3

# load labels from .mat file
labels_mat = scipy.io.loadmat("imagelabels.mat")
labels = labels_mat['labels'][0]

#display data

for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.axis("off")
    # display img
    plt.imshow(img.permute(1,2,0))
    # get the class name using the label
    class_index = labels[sample_idx] - 1
    plt.title(class_index)
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(len(labels))
labels
# Out:
# 8189
# array([77, 77, 77, ..., 62, 62, 62], dtype=uint8)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(150528, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 102),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()

learning_rate = 1e-3
batch_size = 64
epochs = 5

# %%
# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 4.660076  [   64/ 1020]
# Test Error:
#  Accuracy: 3.3%, Avg loss: 4.581875
#
# Epoch 2
# -------------------------------
# loss: 4.542712  [   64/ 1020]
# Test Error:
#  Accuracy: 3.8%, Avg loss: 4.544577
#
# Epoch 3
# -------------------------------
# loss: 4.423135  [   64/ 1020]
# Test Error:
#  Accuracy: 4.3%, Avg loss: 4.501224
#
# Epoch 4
# -------------------------------
# loss: 4.315633  [   64/ 1020]
# Test Error:
#  Accuracy: 5.4%, Avg loss: 4.465600
#
# Epoch 5
# -------------------------------
# loss: 4.228323  [   64/ 1020]
# Test Error:
#  Accuracy: 5.7%, Avg loss: 4.425743
#
# Epoch 6
# -------------------------------
# loss: 4.134814  [   64/ 1020]
# Test Error:
#  Accuracy: 6.8%, Avg loss: 4.388075
#
# Epoch 7
# -------------------------------
# loss: 3.982843  [   64/ 1020]
# Test Error:
#  Accuracy: 6.7%, Avg loss: 4.354755
#
# Epoch 8
# -------------------------------
# loss: 3.812597  [   64/ 1020]
# Test Error:
#  Accuracy: 6.8%, Avg loss: 4.320269
#
# Epoch 9
# -------------------------------
# loss: 3.864180  [   64/ 1020]
# Test Error:
#  Accuracy: 7.3%, Avg loss: 4.286335
#
# Epoch 10
# -------------------------------
# loss: 3.780861  [   64/ 1020]
# Test Error:
#  Accuracy: 7.8%, Avg loss: 4.257428
#
# Done!
